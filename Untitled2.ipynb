# %% [markdown]
# 今日上課內容為如何快速處理資料

# %%
def hello():
  print('hello')

# %%
def hello(x,y=10):
  z=x+y
  print(z)

# %%
def hello(name,age):
  msg=f'{name}is{age}years old'
  print(msg)

# %%
def a(x,y):
  result=x+y*2
  return result

b=a(1,2)
c=a(2,3)

# %%
print(b)
print(c)
# Out:
# 5
# 10

# %%
def a(x):
  result=0
  while result<10:
    result=result+x
    if result==5:
      return result
  return result

b=a(1)
c=a(2)

# %%
print(b)
print(c)
# Out:
# 5
# 10

# %%
def tf(value):
 return 2*value-1
test_values=[0.0,0.0011,0.25,0.5,0,54,0.75,1.0]
scaled_values=[tf(value) for value in test_values]
print("Original values:",test_values)
print("Scaled values:",scaled_values)
# Out:
# Original values: [0.0, 0.0011, 0.25, 0.5, 0, 54, 0.75, 1.0]
# Scaled values: [-1.0, -0.9978, -0.5, 0.0, -1, 107, 0.5, 1.0]

# %%
def a(n):
  if n == 0 or n==1:
    return 1
  else:
    return n + a(n-1)
print(a(0))
print(a(1))
print(a(2))
print(a(3))
# Out:
# 1
# 1
# 3
# 6

# %%
with open('test.txt','w')as f1:
 f1.write('good morning')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:56:50.325539
# 2024-09-26

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:58:16.321502
# 2024-09-26

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760
# 2013-01-05  0.660873  0.354107  0.045432  0.101399
# 2013-01-06  0.180070 -1.417944  0.535761  1.567665

# %%
df.head()
df.tail(3)
df.index
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760
# 2013-01-05  0.660873  0.354107  0.045432  0.101399

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760
# 2013-01-05  0.660873  0.354107  0.045432  0.101399
# 2013-01-06  0.180070 -1.417944  0.535761  1.567665

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2 = df.copy()
df2.to_numpy()
# Out:
# array([[-0.98832397, -0.71576116,  1.78488149,  1.5659601 ],
#        [ 1.08132156,  0.56450589,  0.05750467, -0.5528243 ],
#        [-0.12897528, -1.1514628 ,  0.29198414,  0.27542522],
#        [-1.92137183,  1.1298544 ,  0.38197679, -0.32575981],
#        [ 0.66087312,  0.35410746,  0.04543189,  0.10139935],
#        [ 0.18006965, -1.41794422,  0.53576069,  1.56766526]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.186068 -0.206117  0.516257  0.438644
# std    1.105965  1.030968  0.649653  0.922304
# min   -1.921372 -1.417944  0.045432 -0.552824
# 25%   -0.773487 -1.042537  0.116125 -0.218970
# 50%    0.025547 -0.180827  0.336980  0.188412
# 75%    0.540672  0.511906  0.497315  1.243326
# max    1.081322  1.129854  1.784881  1.567665

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.988324    1.081322   -0.128975   -1.921372    0.660873    0.180070
# B   -0.715761    0.564506   -1.151463    1.129854    0.354107   -1.417944
# C    1.784881    0.057505    0.291984    0.381977    0.045432    0.535761
# D    1.565960   -0.552824    0.275425   -0.325760    0.101399    1.567665

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.565960  1.784881 -0.715761 -0.988324
# 2013-01-02 -0.552824  0.057505  0.564506  1.081322
# 2013-01-03  0.275425  0.291984 -1.151463 -0.128975
# 2013-01-04 -0.325760  0.381977  1.129854 -1.921372
# 2013-01-05  0.101399  0.045432  0.354107  0.660873
# 2013-01-06  1.567665  0.535761 -1.417944  0.180070

# %%
df["A"]
# Out:
# 2013-01-01   -0.988324
# 2013-01-02    1.081322
# 2013-01-03   -0.128975
# 2013-01-04   -1.921372
# 2013-01-05    0.660873
# 2013-01-06    0.180070
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425

# %%
df.loc[dates[0]]
# Out:
# A   -0.988324
# B   -0.715761
# C    1.784881
# D    1.565960
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -0.988324 -0.715761
# 2013-01-02  1.081322  0.564506
# 2013-01-03 -0.128975 -1.151463
# 2013-01-04 -1.921372  1.129854
# 2013-01-05  0.660873  0.354107
# 2013-01-06  0.180070 -1.417944

# %%
df.loc["20130102":"20130104",["A","B"]]
# Out:
#                    A         B
# 2013-01-02  1.081322  0.564506
# 2013-01-03 -0.128975 -1.151463
# 2013-01-04 -1.921372  1.129854

# %%
df.loc[dates[0],"A"]
# Out:
# -0.9883239749664197

# %%
df.iloc[3]
# Out:
# A   -1.921372
# B    1.129854
# C    0.381977
# D   -0.325760
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.921372  1.129854
# 2013-01-05  0.660873  0.354107

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  1.784881  1.565960
# 2013-01-02  1.081322  0.564506  0.057505       NaN
# 2013-01-03       NaN       NaN  0.291984  0.275425
# 2013-01-04       NaN  1.129854  0.381977       NaN
# 2013-01-05  0.660873  0.354107  0.045432  0.101399
# 2013-01-06  0.180070       NaN  0.535761  1.567665

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824
# 2013-01-05  0.660873  0.354107  0.045432  0.101399
# 2013-01-06  0.180070 -1.417944  0.535761  1.567665

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425   two
# 2013-01-05  0.660873  0.354107  0.045432  0.101399  four

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -0.988324 -0.715761 -1.784881 -1.565960
# 2013-01-02 -1.081322 -0.564506 -0.057505 -0.552824
# 2013-01-03 -0.128975 -1.151463 -0.291984 -0.275425
# 2013-01-04 -1.921372 -1.129854 -0.381977 -0.325760
# 2013-01-05 -0.660873 -0.354107 -0.045432 -0.101399
# 2013-01-06 -0.180070 -1.417944 -0.535761 -1.567665

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960  1.0
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824  1.0
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425  NaN
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760  NaN

# %%
df1.dropna( )
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960  1.0
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824  1.0

# %%
df1.fillna(5)
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960  1.0
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824  1.0
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425  5.0
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760  5.0

# %%
df1.interpolate( )
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.988324 -0.715761  1.784881  1.565960  1.0
# 2013-01-02  1.081322  0.564506  0.057505 -0.552824  1.0
# 2013-01-03 -0.128975 -1.151463  0.291984  0.275425  1.0
# 2013-01-04 -1.921372  1.129854  0.381977 -0.325760  1.0

# %%
df.mean()
# Out:
# A   -0.186068
# B   -0.206117
# C    0.516257
# D    0.438644
# dtype: float64

# %%
df.std()
# Out:
# A    1.105965
# B    1.030968
# C    0.649653
# D    0.922304
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.411689
# 2013-01-02    0.287627
# 2013-01-03   -0.178257
# 2013-01-04   -0.183825
# 2013-01-05    0.290453
# 2013-01-06    0.216388
# Freq: D, dtype: float64

# %%
df.std(axis = 1)
# Out:
# 2013-01-01    1.466195
# 2013-01-02    0.699030
# 2013-01-03    0.677375
# 2013-01-04    1.301934
# 2013-01-05    0.281093
# 2013-01-06    1.238320
# Freq: D, dtype: float64
